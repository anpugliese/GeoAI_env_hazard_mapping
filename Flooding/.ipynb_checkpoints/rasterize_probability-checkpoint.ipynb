# %%
import xarray as xr
import numpy as np
import pandas as pd
import rasterio as rio
import rioxarray as rxr
import datacube

# %%
base_folder = f'predictions'
file_name = 'rf_flood_prob_cf_year_no_river_bed.csv'
prob = pd.read_csv(f'{base_folder}/{file_name}', index_col=0)

# %%
prob = prob.dropna()

# %%
da = prob.set_index(['y', 'x']).to_xarray()

# promote the data variables model lat/long to 2d coordinates
#da = da.set_coords(['model_lat', 'model_long'])

#da.res.rio.to_raster(filepath)

# %%
da
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 8785, x: 13198)
# Coordinates:
#   * y            (y) float64 5.003e+06 5.003e+06 ... 5.054e+06 5.054e+06
#   * x            (x) float64 4.771e+05 4.771e+05 ... 5.430e+05 5.431e+05
# Data variables:
#     probability  (y, x) float64 nan nan nan nan nan nan ... nan nan nan nan nan

# %%
fill_y = np.arange(np.min(prob['y']),np.max(prob['y'])+5, 5)
fill_y
# Out:
# array([5003465., 5003470., 5003475., ..., 5054270., 5054275., 5054280.])

# %%
da_fill = da.reindex({'y':fill_y})
da_fill
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 10164, x: 13198)
# Coordinates:
#   * y            (y) float64 5.003e+06 5.003e+06 ... 5.054e+06 5.054e+06
#   * x            (x) float64 4.771e+05 4.771e+05 ... 5.430e+05 5.431e+05
# Data variables:
#     probability  (y, x) float64 nan nan nan nan nan nan ... nan nan nan nan nan

# %%
da_fill.rio.to_raster('Maps/rf_flood_prob_cf_year_no_river_bed.tif')

# %%
# !rio info rf_flood_prob_cf_year_no_river_bed.tif
# Out:
# {"bounds": [477065.0, 5054285.0, 543060.0, 5000995.0], "colorinterp": ["gray"], "count": 1, "crs": null, "descriptions": ["probability"], "driver": "GTiff", "dtype": "float32", "height": 10658, "indexes": [1], "interleave": "band", "mask_flags": [["all_valid"]], "nodata": null, "res": [5.0, 5.0], "shape": [10658, 13199], "tiled": false, "transform": [5.0, 0.0, 477065.0, 0.0, 5.0, 5000995.0, 0.0, 0.0, 1.0], "units": [null], "width": 13199}
