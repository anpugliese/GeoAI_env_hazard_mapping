# %% [markdown]
# # Data_download_MILANO_hourly_meteo

# %%
#----------------Utils--------------------------
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import requests

# %%
def show_plot(df, x_col, y_col, name="Unnamed Plot", additional_traces=[]):
    if type(df) != list:
        df = [df]
        x_col = [x_col]
        y_col = [y_col]
        name = [name]
    
    fig = go.Figure()
    for i, single_df in enumerate(df):
        x = single_df[x_col[i]]
        y = single_df[y_col[i]]
        fig_name = name[i]
        fig.add_trace(go.Scatter(x=x, y=y, mode='lines+markers',name=fig_name))
    
    if len(additional_traces) > 0:
        for trace in additional_traces:
            fig.add_trace(trace)
    fig.show()
    
def import_df(path, date_format="%Y-%m-%dT%H:%M:%S"):
    df = pd.read_csv(path, index_col = 0)
    if date_format is not None:
        df['date'] = pd.to_datetime(df['date'],  format=date_format)
    return df


#Remove Outliers function
#This remove a point if it exceeds +-3 std deviations in a window of "window" observations 
# at column "value_column"
def filter_outliers(input_df, sensor_list, value_column='value'):
    filtered_df = pd.DataFrame()
    for sensor in sensor_list:
        df = input_df.copy()
        df = df.loc[df['sensor_id'] == sensor]
        #iterate all the df
        df['mean']= df[value_column].mean()
        df['std'] = df[value_column].std()
        df
        #filter setup
        df = df[(df[value_column] <= df['mean']+3*df['std']) & (df[value_column] >= df['mean']-3*df['std'])]
        
        filtered_df = pd.concat([filtered_df, df])
    
    filtered_df = filtered_df.drop(["mean", "std"], axis=1)
    return filtered_df

# %%
#GLOBAL VARIABLES
headers = {'Accept': 'application/json'}

milano_data_basepath = "http://localhost:8000/api/collections/"
milano_sensor_base_path = "http://localhost:8000/api/collections/meteosensor/items?"

download = True

date_format = '%Y-%m-%dT%H:%M:%S'

meteo_variables = ["Temperature", "Wind Velocity", "Wind Direction", "Humidity", "Global Radiation", "Precipitation"]

#build the meteo datasets object with the value column of each dataset and the csv name
meteo_datasets = {
    "Temperature": {"collection_name": "temperature", "csv_name": "temperature"},
    "Precipitation": {"collection_name": "precipitation", "csv_name": "precipitation"},
    "Wind Direction": {"collection_name": "winddirection", "csv_name": "wind_direction"},
    "Wind Velocity": {"collection_name": "windvelocity", "csv_name": "wind_velocity"},
    "Global Radiation": {"collection_name": "solarradiation", "csv_name": "radiation"},
    "Humidity": {"collection_name": "humidity", "csv_name": "humidity"},
}

stations_data = []
#fetch the paths to be called to the HARMONIA API
for variable in meteo_variables:
    variable_collection = meteo_datasets[variable]["collection_name"]
    print(f"fetching paths for {variable}")
    sensor_req = requests.get(
        f'{milano_sensor_base_path}sensor_type={variable}&province=MI', 
        headers=headers
    )
    print(f'{milano_sensor_base_path}sensor_type={variable}&province=MI')
    sensors_list = sensor_req.json()
    print(sensors_list)
    variable_stations = list(map(lambda a: a['sensor_id'], sensors_list))
    variable_paths = []
    for station in variable_stations:
        variable_paths.append(f"{milano_data_basepath}{variable_collection}/items?sensor_id={station}&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true")

    meteo_datasets[variable]['paths'] = variable_paths.copy()
    meteo_datasets[variable]['sensors'] = variable_stations.copy()
    stations_data = stations_data + sensors_list.copy()
    print(f"END fetching paths for {variable}")
    print(f"----------------------------------------")

#extract information of the meteo stations from the sensors list.
# this data is then merged with the meteo observations to complement the list.
#drop_cols = ['nomestazione', 'datastart', 'storico', 'cgb_nord', 'cgb_est', 'location', ':@computed_region_6hky_swhk', ':@computed_region_ttgh_9sm5', 'datastop', 'wkb_geometry']
stations_data_df = pd.DataFrame(stations_data)
#stations_data_df = stations_data_df.drop(columns=drop_cols)
# Out:
# fetching paths for Temperature
# http://localhost:8000/api/collections/meteosensor/items?sensor_type=Temperature&province=MI
# [{'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 100, 'station_name': 'Milano Lambrate', 'altitude': 120, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-29', 'date_stop': None, 'utm_north': '5038171.0000', 'utm_east': '520120.0000', 'latitude': '45.4968', 'longitude': '9.2575', 'id': 2001, 'sensor_id': 2001}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 102, 'station_name': 'San Colombano al Lambro', 'altitude': 140, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-27', 'date_stop': None, 'utm_north': '5002165.0000', 'utm_east': '538425.0000', 'latitude': '45.1719', 'longitude': '9.4890', 'id': 2039, 'sensor_id': 2039}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 104, 'station_name': 'Segrate Milano Due', 'altitude': 120, 'province': 'MI', 'is_historical': True, 'date_start': '1995-06-21', 'date_stop': '2004-06-16', 'utm_north': '5038760.0000', 'utm_east': '520713.0000', 'latitude': '45.5021', 'longitude': '9.2651', 'id': 2063, 'sensor_id': 2063}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 140, 'station_name': 'Motta Visconti SMR', 'altitude': 100, 'province': 'MI', 'is_historical': True, 'date_start': '2003-05-23', 'date_stop': '2020-08-25', 'utm_north': '5014273.0000', 'utm_east': '499103.0000', 'latitude': '45.2820', 'longitude': '8.9886', 'id': 4001, 'sensor_id': 4001}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 147, 'station_name': 'Cinisello Balsamo Parco Nord', 'altitude': 142, 'province': 'MI', 'is_historical': False, 'date_start': '2002-05-30', 'date_stop': None, 'utm_north': '5043257.0000', 'utm_east': '516051.0000', 'latitude': '45.5427', 'longitude': '9.2056', 'id': 4058, 'sensor_id': 4058}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 148, 'station_name': 'Arconate SMR', 'altitude': 182, 'province': 'MI', 'is_historical': False, 'date_start': '2002-07-02', 'date_stop': None, 'utm_north': '5043898.0000', 'utm_east': '488082.0000', 'latitude': '45.5485', 'longitude': '8.8473', 'id': 4066, 'sensor_id': 4066}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 620, 'station_name': 'Milano v.Brera', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1990-03-19', 'date_stop': None, 'utm_north': '5035365.0000', 'utm_east': '514782.0000', 'latitude': '45.4717', 'longitude': '9.1891', 'id': 5897, 'sensor_id': 5897}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 525, 'station_name': 'Corsico v.le Italia', 'altitude': 119, 'province': 'MI', 'is_historical': False, 'date_start': '1997-02-12', 'date_stop': None, 'utm_north': '5031403.0000', 'utm_east': '507619.0000', 'latitude': '45.4361', 'longitude': '9.0974', 'id': 5903, 'sensor_id': 5903}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 502, 'station_name': 'Milano v.Juvara', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1989-01-01', 'date_stop': None, 'utm_north': '5035546.0000', 'utm_east': '517377.0000', 'latitude': '45.4732', 'longitude': '9.2223', 'id': 5909, 'sensor_id': 5909}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 535, 'station_name': 'Lacchiarella v.Molise', 'altitude': 97, 'province': 'MI', 'is_historical': False, 'date_start': '1998-09-15', 'date_stop': None, 'utm_north': '5019010.0000', 'utm_east': '510542.0000', 'latitude': '45.3245', 'longitude': '9.1345', 'id': 5910, 'sensor_id': 5910}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 501, 'station_name': 'Milano v.Marche', 'altitude': 129, 'province': 'MI', 'is_historical': False, 'date_start': '1989-01-01', 'date_stop': None, 'utm_north': '5038105.0000', 'utm_east': '514918.0000', 'latitude': '45.4963', 'longitude': '9.1909', 'id': 5911, 'sensor_id': 5911}, {'sensor_type': 'Temperature', 'measurement_unit': '°C', 'station_id': 614, 'station_name':  ...
# END fetching paths for Temperature
# ----------------------------------------
# fetching paths for Wind Velocity
# http://localhost:8000/api/collections/meteosensor/items?sensor_type=Wind Velocity&province=MI
# [{'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 100, 'station_name': 'Milano Lambrate', 'altitude': 120, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-29', 'date_stop': None, 'utm_north': '5038171.0000', 'utm_east': '520120.0000', 'latitude': '45.4968', 'longitude': '9.2575', 'id': 2003, 'sensor_id': 2003}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 513, 'station_name': "Trezzo sull'Adda v.Nenni", 'altitude': 199, 'province': 'MI', 'is_historical': False, 'date_start': '2001-02-22', 'date_stop': None, 'utm_north': '5051253.0000', 'utm_east': '539618.0000', 'latitude': '45.6137', 'longitude': '9.5081', 'id': 6137, 'sensor_id': 6137}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 102, 'station_name': 'San Colombano al Lambro', 'altitude': 140, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-27', 'date_stop': None, 'utm_north': '5002165.0000', 'utm_east': '538425.0000', 'latitude': '45.1719', 'longitude': '9.4890', 'id': 11734, 'sensor_id': 11734}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 148, 'station_name': 'Arconate SMR', 'altitude': 182, 'province': 'MI', 'is_historical': False, 'date_start': '2012-01-27', 'date_stop': None, 'utm_north': '5043898.0000', 'utm_east': '488082.0000', 'latitude': '45.5485', 'longitude': '8.8473', 'id': 11818, 'sensor_id': 11818}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 147, 'station_name': 'Cinisello Balsamo Parco Nord', 'altitude': 142, 'province': 'MI', 'is_historical': False, 'date_start': '2012-03-09', 'date_stop': None, 'utm_north': '5043257.0000', 'utm_east': '516051.0000', 'latitude': '45.5427', 'longitude': '9.2056', 'id': 14113, 'sensor_id': 14113}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 140, 'station_name': 'Motta Visconti SMR', 'altitude': 100, 'province': 'MI', 'is_historical': True, 'date_start': '2012-05-07', 'date_stop': '2020-08-25', 'utm_north': '5014273.0000', 'utm_east': '499103.0000', 'latitude': '46.1344', 'longitude': '9.3638', 'id': 14160, 'sensor_id': 14160}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 1547, 'station_name': 'Rho Scalo Fiorenza - Tetto', 'altitude': 143, 'province': 'MI', 'is_historical': False, 'date_start': '2015-02-24', 'date_stop': None, 'utm_north': '5040421.0000', 'utm_east': '507155.0000', 'latitude': '45.5173', 'longitude': '9.0916', 'id': 14749, 'sensor_id': 14749}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 1873, 'station_name': 'Abbiategrasso Strada Casalina', 'altitude': 115, 'province': 'MI', 'is_historical': False, 'date_start': '2018-12-28', 'date_stop': None, 'utm_north': '5026799.0000', 'utm_east': '491367.0000', 'latitude': '45.3947', 'longitude': '8.8897', 'id': 17481, 'sensor_id': 17481}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 503, 'station_name': 'Milano P.zza Zavattari', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '2013-09-23', 'date_stop': None, 'utm_north': '5035847.0000', 'utm_east': '511082.0000', 'latitude': '45.4761', 'longitude': '9.1418', 'id': 19004, 'sensor_id': 19004}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 620, 'station_name': 'Milano v.Brera', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '2014-03-25', 'date_stop': None, 'utm_north': '5035365.0000', 'utm_east': '514782.0000', 'latitude': '45.4717', 'longitude': '9.1891', 'id': 19007, 'sensor_id': 19007}, {'sensor_type': 'Wind Velocity', 'measurement_unit': 'm/s', 'station_id': 501, 'station_name': 'Milano v.Marche', 'altitude': 129, 'province': 'MI', 'is_historical': False, 'date_start': '2013-10-29', 'date_stop': None, 'utm_north': '5038105.0000', 'utm_east': '514918.0000', 'latitude': '45.4963', 'longitude': '9.1909', 'id': 19019, 'sensor_id': 19019}, {'sensor_type': ' ...
# END fetching paths for Wind Velocity
# ----------------------------------------
# fetching paths for Wind Direction
# http://localhost:8000/api/collections/meteosensor/items?sensor_type=Wind Direction&province=MI
# [{'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 100, 'station_name': 'Milano Lambrate', 'altitude': 120, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-29', 'date_stop': None, 'utm_north': '5038171.0000', 'utm_east': '520120.0000', 'latitude': '45.4968', 'longitude': '9.2575', 'id': 2005, 'sensor_id': 2005}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 102, 'station_name': 'San Colombano al Lambro', 'altitude': 140, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-27', 'date_stop': None, 'utm_north': '5002165.0000', 'utm_east': '538425.0000', 'latitude': '45.1719', 'longitude': '9.4890', 'id': 2048, 'sensor_id': 2048}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 140, 'station_name': 'Motta Visconti SMR', 'altitude': 100, 'province': 'MI', 'is_historical': True, 'date_start': '2003-05-15', 'date_stop': '2020-08-25', 'utm_north': '5014273.0000', 'utm_east': '499103.0000', 'latitude': '46.1344', 'longitude': '9.3638', 'id': 4006, 'sensor_id': 4006}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 147, 'station_name': 'Cinisello Balsamo Parco Nord', 'altitude': 142, 'province': 'MI', 'is_historical': False, 'date_start': '2002-05-30', 'date_stop': None, 'utm_north': '5043257.0000', 'utm_east': '516051.0000', 'latitude': '45.5427', 'longitude': '9.2056', 'id': 4062, 'sensor_id': 4062}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 148, 'station_name': 'Arconate SMR', 'altitude': 182, 'province': 'MI', 'is_historical': False, 'date_start': '2002-07-02', 'date_stop': None, 'utm_north': '5043898.0000', 'utm_east': '488082.0000', 'latitude': '45.5485', 'longitude': '8.8473', 'id': 4071, 'sensor_id': 4071}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 620, 'station_name': 'Milano v.Brera', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1999-11-18', 'date_stop': None, 'utm_north': '5035365.0000', 'utm_east': '514782.0000', 'latitude': '45.4717', 'longitude': '9.1891', 'id': 6029, 'sensor_id': 6029}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 525, 'station_name': 'Corsico v.le Italia', 'altitude': 119, 'province': 'MI', 'is_historical': False, 'date_start': '1999-11-02', 'date_stop': None, 'utm_north': '5031403.0000', 'utm_east': '507619.0000', 'latitude': '45.4361', 'longitude': '9.0974', 'id': 6038, 'sensor_id': 6038}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 502, 'station_name': 'Milano v.Juvara', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5035546.0000', 'utm_east': '517377.0000', 'latitude': '45.4732', 'longitude': '9.2223', 'id': 6044, 'sensor_id': 6044}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 535, 'station_name': 'Lacchiarella v.Molise', 'altitude': 97, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5019010.0000', 'utm_east': '510542.0000', 'latitude': '45.3245', 'longitude': '9.1345', 'id': 6046, 'sensor_id': 6046}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 501, 'station_name': 'Milano v.Marche', 'altitude': 129, 'province': 'MI', 'is_historical': False, 'date_start': '1999-11-17', 'date_stop': None, 'utm_north': '5038105.0000', 'utm_east': '514918.0000', 'latitude': '45.4963', 'longitude': '9.1909', 'id': 6048, 'sensor_id': 6048}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id': 513, 'station_name': "Trezzo sull'Adda v.Nenni", 'altitude': 199, 'province': 'MI', 'is_historical': False, 'date_start': '2001-02-22', 'date_stop': None, 'utm_north': '5051253.0000', 'utm_east': '539618.0000', 'latitude': '45.6137', 'longitude': '9.5081', 'id': 6060, 'sensor_id': 6060}, {'sensor_type': 'Wind Direction', 'measurement_unit': '°', 'station_id' ...
# END fetching paths for Wind Direction
# ----------------------------------------
# fetching paths for Humidity
# http://localhost:8000/api/collections/meteosensor/items?sensor_type=Humidity&province=MI
# [{'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 100, 'station_name': 'Milano Lambrate', 'altitude': 120, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-29', 'date_stop': None, 'utm_north': '5038171.0000', 'utm_east': '520120.0000', 'latitude': '45.4968', 'longitude': '9.2575', 'id': 2002, 'sensor_id': 2002}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 102, 'station_name': 'San Colombano al Lambro', 'altitude': 140, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-27', 'date_stop': None, 'utm_north': '5002165.0000', 'utm_east': '538425.0000', 'latitude': '45.1719', 'longitude': '9.4890', 'id': 2040, 'sensor_id': 2040}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 104, 'station_name': 'Segrate Milano Due', 'altitude': 120, 'province': 'MI', 'is_historical': True, 'date_start': '1995-06-21', 'date_stop': '2004-06-16', 'utm_north': '5038760.0000', 'utm_east': '520713.0000', 'latitude': '45.5021', 'longitude': '9.2651', 'id': 2064, 'sensor_id': 2064}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 140, 'station_name': 'Motta Visconti SMR', 'altitude': 100, 'province': 'MI', 'is_historical': True, 'date_start': '2003-05-15', 'date_stop': '2020-08-25', 'utm_north': '5014273.0000', 'utm_east': '499103.0000', 'latitude': '45.2820', 'longitude': '8.9886', 'id': 4002, 'sensor_id': 4002}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 147, 'station_name': 'Cinisello Balsamo Parco Nord', 'altitude': 142, 'province': 'MI', 'is_historical': False, 'date_start': '2002-05-30', 'date_stop': None, 'utm_north': '5043257.0000', 'utm_east': '516051.0000', 'latitude': '45.5427', 'longitude': '9.2056', 'id': 4059, 'sensor_id': 4059}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 148, 'station_name': 'Arconate SMR', 'altitude': 182, 'province': 'MI', 'is_historical': False, 'date_start': '2002-07-02', 'date_stop': None, 'utm_north': '5043898.0000', 'utm_east': '488082.0000', 'latitude': '45.5485', 'longitude': '8.8473', 'id': 4067, 'sensor_id': 4067}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 620, 'station_name': 'Milano v.Brera', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '2002-12-05', 'date_stop': None, 'utm_north': '5035365.0000', 'utm_east': '514782.0000', 'latitude': '45.4717', 'longitude': '9.1891', 'id': 6174, 'sensor_id': 6174}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 525, 'station_name': 'Corsico v.le Italia', 'altitude': 119, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5031403.0000', 'utm_east': '507619.0000', 'latitude': '45.4361', 'longitude': '9.0974', 'id': 6176, 'sensor_id': 6176}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 502, 'station_name': 'Milano v.Juvara', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5035546.0000', 'utm_east': '517377.0000', 'latitude': '45.4732', 'longitude': '9.2223', 'id': 6179, 'sensor_id': 6179}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 535, 'station_name': 'Lacchiarella v.Molise', 'altitude': 97, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5019010.0000', 'utm_east': '510542.0000', 'latitude': '45.3245', 'longitude': '9.1345', 'id': 6180, 'sensor_id': 6180}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 614, 'station_name': 'Rodano v.Turati', 'altitude': 112, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5035511.0000', 'utm_east': '527631.0000', 'latitude': '45.4726', 'longitude': '9.3535', 'id': 6183, 'sensor_id': 6183}, {'sensor_type': 'Humidity', 'measurement_unit': '%', 'station_id': 513, 'station_name': "Trezzo sull'Adda v.Nenni", 'altitude': 199, 'pr ...
# END fetching paths for Humidity
# ----------------------------------------
# fetching paths for Global Radiation
# http://localhost:8000/api/collections/meteosensor/items?sensor_type=Global Radiation&province=MI
# [{'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 100, 'station_name': 'Milano Lambrate', 'altitude': 120, 'province': 'MI', 'is_historical': False, 'date_start': '2003-09-12', 'date_stop': None, 'utm_north': '5038171.0000', 'utm_east': '520120.0000', 'latitude': '45.4968', 'longitude': '9.2575', 'id': 2008, 'sensor_id': 2008}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 102, 'station_name': 'San Colombano al Lambro', 'altitude': 140, 'province': 'MI', 'is_historical': False, 'date_start': '2003-09-12', 'date_stop': None, 'utm_north': '5002165.0000', 'utm_east': '538425.0000', 'latitude': '45.1719', 'longitude': '9.4890', 'id': 2044, 'sensor_id': 2044}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 140, 'station_name': 'Motta Visconti SMR', 'altitude': 100, 'province': 'MI', 'is_historical': True, 'date_start': '2008-10-28', 'date_stop': '2020-08-25', 'utm_north': '5014273.0000', 'utm_east': '499103.0000', 'latitude': '45.2820', 'longitude': '8.9886', 'id': 4004, 'sensor_id': 4004}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 147, 'station_name': 'Cinisello Balsamo Parco Nord', 'altitude': 142, 'province': 'MI', 'is_historical': False, 'date_start': '2002-05-30', 'date_stop': None, 'utm_north': '5043257.0000', 'utm_east': '516051.0000', 'latitude': '45.5427', 'longitude': '9.2056', 'id': 4060, 'sensor_id': 4060}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 148, 'station_name': 'Arconate SMR', 'altitude': 182, 'province': 'MI', 'is_historical': False, 'date_start': '2002-07-02', 'date_stop': None, 'utm_north': '5043898.0000', 'utm_east': '488082.0000', 'latitude': '45.5485', 'longitude': '8.8473', 'id': 4069, 'sensor_id': 4069}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 502, 'station_name': 'Milano v.Juvara', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5035546.0000', 'utm_east': '517377.0000', 'latitude': '45.4732', 'longitude': '9.2223', 'id': 6458, 'sensor_id': 6458}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 1873, 'station_name': 'Abbiategrasso Strada Casalina', 'altitude': 115, 'province': 'MI', 'is_historical': False, 'date_start': '2018-12-28', 'date_stop': None, 'utm_north': '5026799.0000', 'utm_east': '491367.0000', 'latitude': '45.3947', 'longitude': '8.8897', 'id': 17479, 'sensor_id': 17479}, {'sensor_type': 'Global Radiation', 'measurement_unit': 'W/m²', 'station_id': 620, 'station_name': 'Milano v.Brera', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '2016-07-08', 'date_stop': None, 'utm_north': '5035365.0000', 'utm_east': '514782.0000', 'latitude': '45.4717', 'longitude': '9.1891', 'id': 19374, 'sensor_id': 19374}]
# END fetching paths for Global Radiation
# ----------------------------------------
# fetching paths for Precipitation
# http://localhost:8000/api/collections/meteosensor/items?sensor_type=Precipitation&province=MI
# [{'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 100, 'station_name': 'Milano Lambrate', 'altitude': 120, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-29', 'date_stop': None, 'utm_north': '5038171.0000', 'utm_east': '520120.0000', 'latitude': '45.4968', 'longitude': '9.2575', 'id': 2006, 'sensor_id': 2006}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 102, 'station_name': 'San Colombano al Lambro', 'altitude': 140, 'province': 'MI', 'is_historical': False, 'date_start': '2001-06-27', 'date_stop': None, 'utm_north': '5002165.0000', 'utm_east': '538425.0000', 'latitude': '45.1719', 'longitude': '9.4890', 'id': 2046, 'sensor_id': 2046}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 104, 'station_name': 'Segrate Milano Due', 'altitude': 120, 'province': 'MI', 'is_historical': True, 'date_start': '1994-09-23', 'date_stop': '2004-06-16', 'utm_north': '5038760.0000', 'utm_east': '520713.0000', 'latitude': '45.5021', 'longitude': '9.2651', 'id': 2065, 'sensor_id': 2065}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 140, 'station_name': 'Motta Visconti SMR', 'altitude': 100, 'province': 'MI', 'is_historical': True, 'date_start': '2003-05-15', 'date_stop': '2020-08-25', 'utm_north': '5014273.0000', 'utm_east': '499103.0000', 'latitude': '45.2820', 'longitude': '8.9886', 'id': 4008, 'sensor_id': 4008}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 147, 'station_name': 'Cinisello Balsamo Parco Nord', 'altitude': 142, 'province': 'MI', 'is_historical': False, 'date_start': '2002-05-30', 'date_stop': None, 'utm_north': '5043257.0000', 'utm_east': '516051.0000', 'latitude': '45.5427', 'longitude': '9.2056', 'id': 4065, 'sensor_id': 4065}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 148, 'station_name': 'Arconate SMR', 'altitude': 182, 'province': 'MI', 'is_historical': False, 'date_start': '2009-03-05', 'date_stop': None, 'utm_north': '5043898.0000', 'utm_east': '488082.0000', 'latitude': '45.5485', 'longitude': '8.8473', 'id': 4112, 'sensor_id': 4112}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 525, 'station_name': 'Corsico v.le Italia', 'altitude': 119, 'province': 'MI', 'is_historical': False, 'date_start': '2002-03-29', 'date_stop': None, 'utm_north': '5031403.0000', 'utm_east': '507619.0000', 'latitude': '45.4361', 'longitude': '9.0974', 'id': 5902, 'sensor_id': 5902}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 502, 'station_name': 'Milano v.Juvara', 'altitude': 122, 'province': 'MI', 'is_historical': False, 'date_start': '1989-01-01', 'date_stop': None, 'utm_north': '5035546.0000', 'utm_east': '517377.0000', 'latitude': '45.4732', 'longitude': '9.2223', 'id': 5908, 'sensor_id': 5908}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 614, 'station_name': 'Rodano v.Turati', 'altitude': 112, 'province': 'MI', 'is_historical': False, 'date_start': '1999-01-01', 'date_stop': None, 'utm_north': '5035511.0000', 'utm_east': '527631.0000', 'latitude': '45.4726', 'longitude': '9.3535', 'id': 5916, 'sensor_id': 5916}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 513, 'station_name': "Trezzo sull'Adda v.Nenni", 'altitude': 199, 'province': 'MI', 'is_historical': False, 'date_start': '2001-02-21', 'date_stop': None, 'utm_north': '5051253.0000', 'utm_east': '539618.0000', 'latitude': '45.6137', 'longitude': '9.5081', 'id': 5918, 'sensor_id': 5918}, {'sensor_type': 'Precipitation', 'measurement_unit': 'mm', 'station_id': 890, 'station_name': 'Milano v.Confalonieri', 'altitude': 122, 'province': 'MI', 'is_historical': True, 'date_start': '2006-06-28', 'date_stop': '2012-04-02', 'utm_north': '5037078.0000', 'utm_east': '515100.0000', 'latitude': '45.4871', 'longitude': '9.1932', 'id': 8149, 'sensor_id': 8149}, {'sensor_type': 'Precipitation', 'measurement_unit': ...
# END fetching paths for Precipitation
# ----------------------------------------

# %%
float(stations_data_df.loc[stations_data_df["sensor_id"] == 2001]["latitude"].values[0])
# Out:
# 45.4968

# %%
#request data from the HARMONIA API
headers = {'Accept': 'application/json'}

for variable in meteo_variables:
    print(f"fetching data for {variable}")
    variable_data = []

    for variable_path in meteo_datasets[variable]['paths']:
        print(f'fetching {variable_path}')
        r = requests.get(variable_path, headers=headers)
        req_data = r.json()
        req_features = req_data["features"]

        if len(req_features) > 0:
            sensor_id = req_features[0]["properties"]["sensor_id"]
            lat = float(stations_data_df.loc[stations_data_df["sensor_id"] == sensor_id]["latitude"].values[0])
            lng = float(stations_data_df.loc[stations_data_df["sensor_id"] == sensor_id]["longitude"].values[0])

            req_list = list(map(lambda element: {
                #"id": element["id"],
                "date": element["properties"]["date"],
                "sensor_id": element["properties"]["sensor_id"],
                "value": float(element["properties"]["value"]),
                "lat": lat,
                "lng": lng
            }, req_features))
            variable_data += req_list
            
    print(f"END fetching data for {variable}")

    print(f'Building DF for {variable}')
    df = pd.DataFrame(variable_data)
    meteo_datasets[variable]['raw'] = df.copy()
    df = df.replace(-9999, np.nan).dropna(subset=['value'])
    df['date'] = pd.to_datetime(df['date'],  format=date_format)
    df = filter_outliers(df, meteo_datasets[variable]['sensors'], 'value')
    df = df.sort_values(by='date')
    meteo_datasets[variable]['df'] = df.copy()
    print(f'END Building DF for {variable}')
    print(f"----------------------------------------")
# Out:
# fetching data for Temperature
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=2001&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=2039&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=2063&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=4001&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=4058&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=4066&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5897&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5903&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5909&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5910&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5911&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5917&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=5920&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=8162&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=12757&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=12759&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=14742&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/temperature/items?sensor_id=17488&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# END fetching data for Temperature
# Building DF for Temperature
# END Building DF for Temperature
# ----------------------------------------
# fetching data for Wind Velocity
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=2003&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=6137&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=11734&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=11818&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=14113&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=14160&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=14749&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=17481&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=19004&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=19007&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=19019&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=19058&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=19061&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/windvelocity/items?sensor_id=19242&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# END fetching data for Wind Velocity
# Building DF for Wind Velocity
# END Building DF for Wind Velocity
# ----------------------------------------
# fetching data for Wind Direction
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=2005&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=2048&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=4006&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=4062&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=4071&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6029&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6038&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6044&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6046&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6048&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6060&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=6063&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=14748&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/winddirection/items?sensor_id=17483&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# END fetching data for Wind Direction
# Building DF for Wind Direction
# END Building DF for Wind Direction
# ----------------------------------------
# fetching data for Humidity
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=2002&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=2040&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=2064&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=4002&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=4059&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=4067&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6174&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6176&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6179&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6180&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6183&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6184&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6185&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=6597&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=12758&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=12760&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=14745&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/humidity/items?sensor_id=17491&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# END fetching data for Humidity
# Building DF for Humidity
# END Building DF for Humidity
# ----------------------------------------
# fetching data for Global Radiation
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=2008&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=2044&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=4004&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=4060&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=4069&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=6458&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=17479&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/solarradiation/items?sensor_id=19374&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# END fetching data for Global Radiation
# Building DF for Global Radiation
# END Building DF for Global Radiation
# ----------------------------------------
# fetching data for Precipitation
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=2006&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=2046&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=2065&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=4008&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=4065&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=4112&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=5902&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=5908&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=5916&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=5918&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=8149&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=8692&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=9341&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=14121&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=14741&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=17487&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=19373&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=30525&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=30536&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# fetching http://localhost:8000/api/collections/precipitation/items?sensor_id=30539&datetime=2022-01-01/2023-12-31&limit=1000000&f=geojson&skipGeometry=true
# END fetching data for Precipitation
# Building DF for Precipitation
# END Building DF for Precipitation
# ----------------------------------------

# %%
meteo_datasets['Precipitation']['df'].rename(columns={'sensor_id': 'sensorID'})
# Out:
#               date  sensorID  value      lat     lng
# 725850  2022-01-01      5918    0.0  45.6137  9.5081
# 743270  2022-01-01      9341    0.0  45.4761  9.1418
# 625778  2022-01-01      5916    0.0  45.4726  9.3535
# 1368668 2022-01-01     30536    0.0  45.6078  8.9529
# 520864  2022-01-01      5908    0.0  45.4732  9.2223
# ...            ...       ...    ...      ...     ...
# 952671  2023-12-31     14121    0.0  45.4901  9.1944
# 416806  2023-12-31      4112    0.0  45.5485  8.8473
# 847781  2023-12-31      9341    0.0  45.4761  9.1418
# 1263755 2023-12-31     19373    0.0  45.4717  9.1891
# 1578488 2023-12-31     30539    0.0  45.5356  9.0052
#
# [1570170 rows x 5 columns]

# %%
import_df('../data/milano_meteo_data/precipitation.csv',1998,2023)
# Out:
#          sensorID        lat       lng                date  value
# 0            5908  45.473226  9.222315 1998-01-01 00:00:00    0.4
# 1            5908  45.473226  9.222315 1998-01-01 02:00:00    0.2
# 2            5908  45.473226  9.222315 1998-01-01 03:00:00    0.0
# 3            5908  45.473226  9.222315 1998-01-01 04:00:00    0.2
# 4            5908  45.473226  9.222315 1998-01-01 05:00:00    0.0
# ...           ...        ...       ...                 ...    ...
# 3826265     14121  45.490100  9.194400 2023-12-31 00:00:00    0.0
# 3826266      4112  45.548500  8.847300 2023-12-31 00:00:00    0.0
# 3826267      9341  45.476100  9.141800 2023-12-31 00:00:00    0.0
# 3826268     19373  45.471700  9.189100 2023-12-31 00:00:00    0.0
# 3826269     30539  45.535600  9.005200 2023-12-31 00:00:00    0.0
#
# [3826270 rows x 5 columns]

# %%
stations_data_df
# Out:
#     idsensore         tipologia unit_dimisura  idstazione  quota provincia  \
# 0       12757       Temperatura            °C        1511    215        MI
# 1       12759       Temperatura            °C        1512    160        MI
# 2       14742       Temperatura            °C        1546    143        MI
# 3       17488       Temperatura            °C        1874    137        MI
# 4        2001       Temperatura            °C         100    120        MI
# ..        ...               ...           ...         ...    ...       ...
# 93       6180  Umidità Relativa             %         535     97        MI
# 94       6183  Umidità Relativa             %         614    112        MI
# 95       6184  Umidità Relativa             %         513    199        MI
# 96       6185  Umidità Relativa             %         503    122        MI
# 97       6597  Umidità Relativa             %         501    129        MI
#
#          lng        lat
# 0   8.952897  45.607845
# 1   9.005200  45.535577
# 2   9.087923  45.517811
# 3   8.854409  45.458065
# 4   9.257515  45.496780
# ..       ...        ...
# 93  9.134517  45.324517
# 94  9.353497  45.472580
# 95  9.508122  45.613692
# 96  9.141786  45.476063
# 97  9.190934  45.496316
#
# [98 rows x 8 columns]

# %%
def import_df(path, start_year, end_year, date_format="%Y-%m-%d", date_column="date"):
    df = pd.read_csv(path, index_col = 0)
    if date_format is not None and date_column is not None:
        df[date_column] = pd.to_datetime(df[date_column],  format=date_format)
    df = df.loc[
        (df['date'].dt.year >= start_year) &
        (df['date'].dt.year <= end_year)
    ]
    return df

# %%
csv_base_path = '../data/milano_meteo_data'
for variable in meteo_variables:
    name = meteo_datasets[variable]['csv_name']
    legacy = import_df(f'{csv_base_path}/{name}.csv',1998,2021).drop(columns=['type','unit','province','altitude','stationID'])
    new = pd.concat([legacy, meteo_datasets[variable]['df'].rename(columns={'sensor_id': 'sensorID'})])
    new = new.reset_index(drop=True)
    new.to_csv(f'{csv_base_path}/{name}.csv')

# %%
# Building the process-ready datasets
#datasets -> meteo_datasets[variable]['df']
#stations -> stations_data_df
#meteo variables -> meteo_variables

for variable in meteo_variables:
    print(f'Building data-ready dataset for {variable}')
    var_station_data = stations_data_df.loc[stations_data_df['tipologia'] == variable]
    var_df = meteo_datasets[variable]['df'].copy()

    #common columns to drop
    columns_to_drop = ['cgb_nord', 'cgb_est', 'massimo', 'valore_medio_giornaliero', 'minimo_valore_medio_orario', 'massimo_valore_medio_orario']
    var_df = var_df.drop(columns=columns_to_drop)
    var_df = var_df.rename(columns={"sensor_id": "idsensore"})

    #Specific column to drop for precitipation and rename the data column to Valore
    if variable == "Precipitazione":
        var_df = var_df.drop(columns=['medio'])
        var_df = var_df.rename(columns={"valore_cumulato": "valore"})
    else:
        var_df = var_df.drop(columns=['valore_cumulato'])
        var_df = var_df.rename(columns={"medio": "valore"})

    #merge the data with the station information
    var_station_data_merge = var_station_data[['idsensore', 'tipologia', 'unit_dimisura', 'idstazione', 'quota', 'provincia', 'lng', 'lat']]
    var_df = var_df.merge(var_station_data_merge, on=['idsensore', 'lat', 'lng'])

    #rename columns
    column_rename = {
        "idsensore": "sensorID",
        "date": "date",
        "valore": "value",
        "tipologia": "type",
        "unit_dimisura": "unit",
        "idstazione": "stationID",
        "quota": "altitude",
        "provincia": "province"
    }
    var_df = var_df.rename(columns=column_rename)

    meteo_datasets[variable]['df'] = var_df.copy()
    print(f"saving to file {meteo_datasets[variable]['csv_name']}.csv")
    meteo_datasets[variable]['df'].to_csv(f'../data/milano_meteo_data/{meteo_datasets[variable]["csv_name"]}.csv')
# Out:
# Building data-ready dataset for Temperatura
# saving to file AAA_READY_temperature
# Building data-ready dataset for Precipitazione
# saving to file AAA_READY_precipitation
# Building data-ready dataset for Direzione Vento
# saving to file AAA_READY_wind_direction
# Building data-ready dataset for Velocità Vento
# saving to file AAA_READY_wind_velocity
# Building data-ready dataset for Livello Idrometrico
# saving to file AAA_READY_hydrometric_level
# Building data-ready dataset for Radiazione Globale
# saving to file AAA_READY_radiation
# Building data-ready dataset for Umidità Relativa
# saving to file AAA_READY_humidity

# %%
a = import_df(f'../data/milano_meteo_data/temperature.csv')
