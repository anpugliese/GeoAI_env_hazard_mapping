# %% [markdown]
# # Data_download_MILANO_hourly_pollutants

# %%
#----------------Utils--------------------------
import pandas as pd
import plotly
import plotly.graph_objects as go
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import requests

#----------------Interpolation--------------------------
from shapely.geometry import box
from scipy.interpolate import griddata, interpn

from scipy.interpolate import Rbf
from scipy.interpolate import RBFInterpolator
import pykrige

#----------------Machine Learning--------------------------
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error
pd.set_option('display.max_columns', None)


#------------------Export raster-----------------------------
import rasterio
from rasterio.features import rasterize
from rasterio.transform import from_origin
# Out:
# 2023-11-06 14:44:38.345182: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-06 14:44:38.346336: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 14:44:38.368465: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-06 14:44:38.368944: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 14:44:38.729027: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#Remove Outliers function
#This remove a point if it exceeds +-3 std deviations in a window of "window" observations 
# at column "value_column"
def filter_outliers_by_sensor(input_df, window, sensor_list, value_column='value'):
    filtered_df = pd.DataFrame()
    for sensor in sensor_list:
        df = input_df.copy()
        df = df.loc[df['sensor_id'] == sensor]
        #iterate all the df
        df['mean']= df[value_column].rolling(window, center=True, step=1, min_periods=1).mean()
        df['std'] = df[value_column].rolling(window, center=True, step=1, min_periods=1).std()
        df
        #filter setup
        df = df[(df[value_column] <= df['mean']+3*df['std']) & (df[value_column] >= df['mean']-3*df['std'])]
        
        filtered_df = pd.concat([filtered_df, df])
    
    filtered_df = filtered_df.drop(["mean", "std"], axis=1)
    return filtered_df

# %%
#global variables
polution_variables = ['pm10', 'pm25', 'o3', 'no2', 'so2']

pollution_datasets = {
    "pm10": {"value_column": "value", "csv_name": "pm10", "sensor_type": "PM10%20(SM2005)"},
    "pm25": {"value_column": "value", "csv_name": "pm25", "sensor_type": "Particelle%20sospese%20PM2.5"},
    "o3": {"value_column": "value", "csv_name": "o3", "sensor_type": "Ozono"},
    "no2": {"value_column": "value", "csv_name": "no2", "sensor_type": "Biossido%20di%20Azoto"},
    "so2": {"value_column": "value", "csv_name": "so2", "sensor_type": "Biossido%20di%20Zolfo"}
}

date_format = "%Y-%m-%dT%H:%M:%S"

# %%
#DONT RUN IF NOT NECESSARY. IT TAKES TIME TO GET THE ENTIRE DATASET
#MILANO
headers = {'Accept': 'application/json'}
milano_data_basepath = "http://api.harmonia.info.uvt.ro/airquality_data_view?"
milano_sensor_base_path = "http://api.harmonia.info.uvt.ro/airquality_stations?"

for variable in polution_variables:
    pollution_dataset = pollution_datasets[variable]
    sensor_type = pollution_dataset['sensor_type']
    sensor_path = f'{milano_sensor_base_path}nometiposensore=eq.{sensor_type}&provincia=eq.MI'
    #sensor_path = f'{milano_sensor_base_path}nometiposensore=eq.{sensor_type}'
    print(sensor_path)
    
    sensor_req = requests.get(sensor_path, headers=headers)
    sensors_list = sensor_req.json()
    variable_stations = list(map(lambda a: a['idsensore'], sensors_list))
    variable_paths = []
    for station in variable_stations:
        variable_paths.append(f"{milano_data_basepath}sensor_id=eq.{station}")
        
    variable_stations = list(map(lambda a: a['idsensore'], sensors_list))
    variable_paths = []
    for station in variable_stations:
        variable_paths.append(f"{milano_data_basepath}sensor_id=eq.{station}")

    pollution_datasets[variable]['paths'] = variable_paths.copy()
    pollution_datasets[variable]['sensors'] = variable_stations.copy()
# Out:
# http://api.harmonia.info.uvt.ro/airquality_stations?nometiposensore=eq.PM10%20(SM2005)&provincia=eq.MI
# http://api.harmonia.info.uvt.ro/airquality_stations?nometiposensore=eq.Particelle%20sospese%20PM2.5&provincia=eq.MI
# http://api.harmonia.info.uvt.ro/airquality_stations?nometiposensore=eq.Ozono&provincia=eq.MI
# http://api.harmonia.info.uvt.ro/airquality_stations?nometiposensore=eq.Biossido%20di%20Azoto&provincia=eq.MI
# http://api.harmonia.info.uvt.ro/airquality_stations?nometiposensore=eq.Biossido%20di%20Zolfo&provincia=eq.MI

# %%
#request data from the HARMONIA API
headers = {'Accept': 'application/json'}

for variable in polution_variables:
    print(f"fetching data for {variable}")
    variable_data = []

    for variable_path in pollution_datasets[variable]['paths']:
        print(f'fetching {variable_path}')
        r = requests.get(variable_path, headers=headers)
        req_data = r.json()
        variable_data += req_data
        
    print(f"END fetching data for {variable}")
    print(f"Building dataframe for {variable}")
    df = pd.DataFrame(variable_data)
    pollution_datasets[variable]['raw'] = df.copy()
    df = df.drop(["utm_nord", "utm_est"], axis=1)
    df = df.replace(-999.0, np.nan).dropna(subset=[pollution_datasets[variable]['value_column']])
    df['date'] = pd.to_datetime(df['date'],  format=date_format)
    df = df.sort_values(by='date')
    window = 30 #days
    df = filter_outliers_by_sensor(
        df, 
        window,
        pollution_datasets[variable]['sensors'],
        pollution_datasets[variable]['value_column']
    )
    df = df.sort_values(by='date')
    pollution_datasets[variable]['df'] = df.copy()
    print(f"END Building dataframe for {variable}")
# Out:
# fetching data for pm10
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10273
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10320
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10352
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10354
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.20428
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.6905
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.6907
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.6908
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.6909
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.6912
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.6956
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.9963
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.20429
# END fetching data for pm10
# Building dataframe for pm10
# END Building dataframe for pm10
# fetching data for pm25
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10283
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10349
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.17122
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.20358
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.9874
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.20529
# END fetching data for pm25
# Building dataframe for pm25
# END Building dataframe for pm25
# fetching data for o3
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10282
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10350
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5707
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5708
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5710
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5711
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5712
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5713
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5714
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5715
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5717
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5718
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5721
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5722
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5724
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5725
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.9900
# END fetching data for o3
# Building dataframe for o3
# END Building dataframe for o3
# fetching data for no2
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10005
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10279
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5504
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5505
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5506
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5507
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5508
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5511
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5513
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5514
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5516
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5517
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5518
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5519
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5520
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5522
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5528
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5530
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5531
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5532
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5534
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5535
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5538
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5539
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5540
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5541
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5542
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5543
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5547
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5548
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5549
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5550
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5551
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5552
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5554
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5605
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5609
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.9999
# END fetching data for no2
# Building dataframe for no2
# END Building dataframe for no2
# fetching data for so2
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10006
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.10280
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.20427
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5613
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5614
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5617
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5618
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5619
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5620
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5621
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5623
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5624
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5625
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5626
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5627
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5628
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5630
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5631
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5636
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5637
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5638
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5640
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5642
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5643
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5644
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5646
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5647
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5650
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5651
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5694
# fetching http://api.harmonia.info.uvt.ro/airquality_data_view?sensor_id=eq.5696
# END fetching data for so2
# Building dataframe for so2
# END Building dataframe for so2

# %%
#Comment so it is not overwritten "by mistake".
#csv_base_path = f'../../data/lombardy_pollutants_data'
csv_base_path = '../data/milano_pollutant_data'

for variable in polution_variables:
    pollution_datasets[variable]['df'].to_csv(f'{csv_base_path}/MI_{pollution_datasets[variable]["csv_name"]}.csv')
